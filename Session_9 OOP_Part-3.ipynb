# %% [markdown]
# ### Class Relationships
#
# ##### - Aggregation
# ##### - Inheritance

# %% [markdown]
# ### Aggregation(Has-A relationship)

# %%
class customer:

    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address

    def print_address(self): 
        print(self.address.get_city(),self.address.pin,self.address.state)

    def edit_profile(self,new_name,new_city,new_pin,new_state):
        self.name = new_name
        self.address.edit_address(new_city,new_pin,new_state)

## Address is having numbers letters so we can not take it 
## Hence we will take the special class to store address 
class address:

    def __init__(self,city,pin,state):
        self.__city = city
        self.pin = pin
        self.state = state

    def get_city(self):                     #it is defined cause we cant use the private variable in the code(__city)
        return self.__city

    def edit_address(self,new_city,new_pin,new_state):
        self.__city = new_city
        self.pin = new_pin
        self.state = new_state

add1 = address('Nira',412102,'Maharashtra')
cust1 = customer('Majid','Male',add1)

cust1.print_address()

cust1.edit_profile('Saniya','Pune',413133,'Kashmir')
cust1.print_address()
# Out:
# Nira 412102 Maharashtra
# Pune 413133 Kashmir

# %% [markdown]
# ### Inheritance
#
# ##### - What is inheritance
# ##### - Example
# ##### - What gets inherited?

# %%
class user:

    def __init__(self):
        self.name = "Majid"

    def login(self):
        print("Login")


class student(user):

    def __init__(self):
        self.rollno = 100

    def enroll(self):
        print("Enroll into the course")


u =  user()
s = student()

print(s.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 22
#      19 u =  user()
#      20 s = student()
# ---> 22 print(s.name)
#
# AttributeError: 'student' object has no attribute 'name'

# %%
class user:

    def __init__(self):
        self.name = "Majid"

    def login(self):
        print("Login")


class student(user):

    def enroll(self):                         ## Here the name is not the part of the constructor present inside the student classs
        print("Enroll into the course")       ## You can use it only when you are not having your own class


u =  user()
s = student()

print(s.name)
# Out:
# Majid

# %% [markdown]
# ##### What gets inherited?
#
# ##### - Constructor
# ##### - Non Private Attributes
# ##### - Non Private Methods

# %%
# constructor example

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 13)
s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# constructor example 2

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, os, ram):
        self.os = os
        self.ram = ram
        print ("Inside SmartPhone constructor")

s=SmartPhone("Android", 2)
s.brand


# Here the smartphonne is having its own constructor hence its call own constructor hence brand is presnt in the parent class hence we cant take the s.brand
# Out:
# Inside SmartPhone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 17
#      14         print ("Inside SmartPhone constructor")
#      16 s=SmartPhone("Android", 2)
# ---> 17 s.brand
#      20 # Here the smartphonne is having its own constructor hence its call own constructor hence brand is presnt in the parent class hence we cant take the s.brand
#
# AttributeError: 'SmartPhone' object has no attribute 'brand'

# %%
# child can't access private members of the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter
    def show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000, "Apple", 13)
print(s.brand)       ## It is get accessed cause they are public variables
s.check()            ## It is not get acceessed cause they are private variables
# Out:
# Inside phone constructor
# Apple
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 20
#      18 s=SmartPhone(20000, "Apple", 13)
#      19 print(s.brand)       ## It is get accessed cause they are public variables
# ---> 20 s.check()            ## It is not get acceessed cause they are private variables
#
# Cell In[10], line 16, in SmartPhone.check(self)
#      15 def check(self):
# ---> 16     print(self.__price)
#
# AttributeError: 'SmartPhone' object has no attribute '_SmartPhone__price'

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):         # Act as getter element
        return self.__num

class Child(Parent):

    def show(self):
        print("This is in child class")
        
son=Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self,val,num):
        self.__val=val

    def get_val(self):
        return self.__val
        
son=Child(100,10)
print("Parent: Num:",son.get_num())
print("Child: Val:",son.get_val())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 18
#      15         return self.__val
#      17 son=Child(100,10)
# ---> 18 print("Parent: Num:",son.get_num())
#      19 print("Child: Val:",son.get_val())
#
# Cell In[12], line 7, in Parent.get_num(self)
#       6 def get_num(self):
# ----> 7     return self.__num
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
class A:
    def __init__(self):
        self.var1=100

    def display1(self,var1):
        print("class A :", self.var1)
class B(A):
  
    def display2(self,var1):
        print("class B :", self.var1)

obj=B()
obj.display1(200)
# Out:
# class A : 100

# %% [markdown]
# #### Method Overriding

# %%
# Method Overriding
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone

# %% [markdown]
# ### Super Keyword

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# super -> constuctor
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, price, brand, camera, os, ram):
        print('Inside smartphone constructor')
        super().__init__(price, brand, camera)
        self.os = os
        self.ram = ram
        print ("Inside smartphone constructor")

s=SmartPhone(20000, "Samsung", 12, "Android", 2)
print(s.os)
print(s.brand)
# Out:
# Inside smartphone constructor
# Inside phone constructor
# Inside smartphone constructor
# Android
# Samsung

# %%
# Super is always used inside the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.super().buy()
# Out:
# Inside phone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 21
#      17         super().buy()
#      19 s=SmartPhone(20000, "Apple", 13)
# ---> 21 s.super().buy()
#
# AttributeError: 'SmartPhone' object has no attribute 'super'

# %%
# Super is always used inside the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        print(super().brand)

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 21
#      17         print(super().brand)
#      19 s=SmartPhone(20000, "Apple", 13)
# ---> 21 s.buy()
#
# Cell In[4], line 17, in SmartPhone.buy(self)
#      15 print ("Buying a smartphone")
#      16 # syntax to call parent ka buy method
# ---> 17 print(super().brand)
#
# AttributeError: 'super' object has no attribute 'brand'

# %% [markdown]
# ##### Inheritance in summary
#
# ###### - A class can inherit from another class.
#
# ###### - Inheritance improves code reuse
#
# ######  - Constructor, attributes, methods get inherited to the child class
#
# ###### - The parent has no access to the child class
#
# ###### - Private properties of parent are not accessible directly in child class
#
# ###### - Child class can override the attributes or methods. This is called method overriding
#
# ###### - super() is an inbuilt function which is used to invoke the parent class methods and constructor

# %%
class Parent:

    def __init__(self,num):
      self.__num=num

    def get_num(self):
      return self.__num

class Child(Parent):
  
    def __init__(self,num,val):
      super().__init__(num)
      self.__val=val

    def get_val(self):
      return self.__val
      
son=Child(100,200)
print(son.get_num())
print(son.get_val())
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.num=100

class Child(Parent):

    def __init__(self):
        super().__init__()
        self.var=200
        
    def show(self):
        print(self.num)
        print(self.var)

son=Child()
son.show()
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()
# Out:
# Child: 10

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()

# %% [markdown]
# ### Types of Inheritance
#
# ##### - Single Inheritance
# ##### - Multilevel Inheritance
# ##### - Hierarchical Inheritance
# ##### - Multiple Inheritance(Diamond Problem)
# ##### - Hybrid Inheritance

# %%
# single inheritance
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# multilevel
class Product:
    def review(self):
        print ("Product customer review")

class Phone(Product):
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Product customer review

# %%
# Hierarchical
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

class FeaturePhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
FeaturePhone(10,"Lava","1px").buy()
# Out:
# Inside phone constructor
# Buying a phone
# Inside phone constructor
# Buying a phone

# %%
# Multiple
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def review(self):
        print ("Customer review")

class SmartPhone(Phone, Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Customer review

# %%
# the diamond problem
# https://stackoverflow.com/questions/56361048/what-is-the-diamond-problem-in-python-and-why-its-not-appear-in-python2
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def buy(self):
        print ("Product buy method")

# Method resolution order
class SmartPhone(Product,Phone):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
# Out:
# Inside phone constructor
# Product buy method

# %%
# Practice Questions
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        return 30

    def m2(self):
        return 40

class C(B):
  
    def m2(self):
        return 20
obj1=A()
obj2=B()
obj3=C()
print(obj1.m1() + obj3.m1()+ obj3.m2())
# Out:
# 70

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        val=super().m1()+30
        return val

class C(B):
  
    def m1(self):
        val=self.m1()+20
        return val
obj=C()
print(obj.m1())
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[18], line 18
#      16         return val
#      17 obj=C()
# ---> 18 print(obj.m1())
#
# Cell In[18], line 15, in C.m1(self)
#      14 def m1(self):
# ---> 15     val=self.m1()+20
#      16     return val
#
# Cell In[18], line 15, in C.m1(self)
#      14 def m1(self):
# ---> 15     val=self.m1()+20
#      16     return val
#
#     [... skipping similar frames: C.m1 at line 15 (2974 times)]
#
# Cell In[18], line 15, in C.m1(self)
#      14 def m1(self):
# ---> 15     val=self.m1()+20
#      16     return val
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ### Polymorphism
#
# ##### - Method Overriding
# ##### - Method Overloading
# ##### - Operator Overloading

# %%
class Shape:

  def area(self,a,b=0):        # b is deafult variable just use in the code just like even as in the l*b
    if b == 0:
      return 3.14*a*a
    else:
      return a*b

s = Shape()

print(s.area(2))
print(s.area(3,4))
# Out:
# 12.56
# 12

# %%
'hello' + 'world'
# Out:
# 'helloworld'

# %%
4 + 5
# Out:
# 9

# %%
[1,2,3] + [4,5]
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### Abstraction

# %%
# Abstract Method
from abc import ABC,abstractmethod
class BankApp(ABC):

    def database(self):
        print('Connected to database')

    @abstractmethod
    def security(self):
        pass

# %%
class mobileapp(BankApp):

    def mobile_login(self):
        print("login into mobile")

    def security(self):
        print("Mobile Secure")

# %%
mob = mobileapp()

# %%
mob.security()
# Out:
# Mobile Secure

# %%
obj = BankApp()     # We cant create the object of abstract classs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 obj = BankApp()     # We cant create the object of abstract classs
#
# TypeError: Can't instantiate abstract class BankApp without an implementation for abstract method 'security'
